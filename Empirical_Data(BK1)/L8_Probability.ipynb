# %% [markdown]
# # Content
# * [Exercise 8.1: A dice rolls and coin flips](#Exercise-8.1:-A-dice-rolls-and-coin-flips)
# * [Exercise 8.2: Disease inherited by a sex-linked gene](#Exercise-8.2:-Disease-inherited-by-a-sex-linked-gene)
# * [Exercise 8.3: Screening for colon cancer](#Exercise-8.3:-Screening-for-colon-cancer)
# * [Exercise 8.4: Independence of events](#Exercise-8.4:-Independence-of-events)
# * [Exercise 8.5: Frequencies and mean](#Exercise-8.5:-Frequencies-and-mean)

# %% [markdown]
# ## Exercise 8.1: A dice rolls and coin flips

# %% [markdown]
# ### What are the possible outcomes? <span style="color:blue"> (1,2,3,4,5,6) </span>
# ### For each outcome what is the associated probability? <span style="color:blue"> P(k)= $\frac{1}{6}$ </span>

# %% [markdown]
# ### 2. What is the probability that Peter does not throw a 6? <span style="color:blue"> P(k)= 1 -$\frac{1}{6}$ so it is $\frac{5}{6}$

# %% [markdown]
# ### 3. Look at Peters experience in another way. He can throw a 6, in which case he wins or he can throw something else, in which case he looses. We can now consider Peters action as a chance operation with two possible outcomes: Win and Loose. What are the associated probabilities for L and W?
# ###  <span style="color:blue"> Loose = 1,2,3,4,5</span>
# ###  <span style="color:blue"> Win = 6 then it is $\frac{1}{6}$ </span>

# %% [markdown]
# ## Peter now throws two dice.
# ### 4. What are the underlying chance operations? <span style="color:blue"> Toss 2 dices </span>Draw the probability tree.
# ### By the outcome.
# ## <span style="color:blue"> 2 </span>   1+1                                                                           $\frac{1}{36}$
# ## <span style="color:blue"> 3 </span>   1+2,  2+1                                                                  $\frac{2}{36}$
# ## <span style="color:blue"> 4 </span>   1+3,  2+2,  3+1                                                         $\frac{3}{36}$
# ## <span style="color:blue"> 5 </span>   1+4,  2+3,  3+2,  4+1                                                $\frac{4}{36}$
# ## <span style="color:blue"> 6 </span>   2+4,  3+3,  4+2,  5+1,  1+5                                       $\frac{5}{36}$
# ## <span style="color:blue"> 7 </span>   1+6,  2+5,  3+4,  4+3,  5+2,  6+1                              $\frac{6}{36}$
# ## <span style="color:blue"> 8 </span>   2+6,  3+5,  4+4,  5+3,  6+2                                       $\frac{5}{36}$
# ## <span style="color:blue"> 9 </span>   3+6,  4+5,  5+4,  6+3                                                $\frac{4}{36}$
# ## <span style="color:blue"> 10 </span>  5+5,  6+4,  4+6                                                         $\frac{3}{36}$
# ## <span style="color:blue"> 11 </span> 5+6,  6+5                                                                   $\frac{2}{36}$
# ## <span style="color:blue"> 12 </span> 6+6                                                                            $\frac{1}{36}$

# %% [markdown]
# ### a) no 6, = <span style="color:blue"> $\frac{25}{36}$ </span>
# ### b) Exactly 1, 6 = <span style="color:blue"> $\frac{1}{36}$ </span>
# ### c) Exactly 2, 6 = <span style="color:blue"> $\frac{1}{36}$ </span>

# %% [markdown]
# ## 6. Optional:* Peters experience can be described by two different probability trees – one with 36 branches and one with 4. Solve Question 4. two times - one for each tree.

# %% [markdown]
# ## Tom flips 3 coins
# ### H H H  =  0.125
# ### H H T  =   0.125
# ### H T H  =   0.125
# ### H T T   =   0.125
# ### T H H   =   0.125
# ### T H T    =   0.125
# ### T T H    =   0.125
# ### T T T    =   0.125
#
# ## 7. What is the probability that he gets at least one head? = <span style="color:blue"> 1 - 0.125 = 0.875 </span>
# ## Hint: What is the probability that he does not get any head? = <span style="color:blue"> 0.125 </span>

# %% [markdown]
# ## Exercise 8.2: Disease inherited by a sex-linked gene

# %% [markdown]
# ### Suppose that a disease is inherited by a sex-linked gene, so that a female off- spring has 50% chance of inheriting the disease while male offspring do not inherit the disease. 51.3% of all births are male. A couple where the woman carries the disease-gene has a child.

# %% [markdown]
# ### 1. What is the probability that their child carries the disease-gene? = <span style="color:blue"> 0.487 * 0.5 = 0.2435 or 24.35% </span>

# %% [markdown]
# ### 2. What are the chance operations? = <span style="color:blue"> Disease inherited,sex</span>
# ###     What are the possible outcomes?= <span style="color:blue"> Male offspring(normal),  Female offspring(normal), Female ofspring(disease) </span>

# %% [markdown]
# ### 3. Make a probability tree and use it to answer the question: What is the probability that a randomly chosen child will inherit the disease?

# %% [markdown]
# <img src="img/ds.png" width= "350" height="200"/>

# %%
from IPython.display import Image
Image(filename="img/ds.png", width=350,height=400)

# %% [markdown]
# ### Exercise 8.3: Screening for colon cancer

# %% [markdown]
# ### In Denmark all persons of age 50-74 years are offered a screening for colon cancer (DK: tarmkræft); specifically the screening tests for blood in the stool. The probability of a false positive is 2% and the probability for a false nega- tive is 40%. About 0.5% of the persons in the age-group have colon cancer. Actually this probability was not really known when the program started, so the 0.5% is the best guess from experts before the screening program started. In the last question we will improve this guess but for now let us assume that 0.5% of the population has colon cancer. Persons with a positive test will be referred to a more detailed test. (See Example 7.8: Medical screening on page 79 for the meaning of false positive and negative.)

# %% [markdown]
# ### 1. Set up the probability tree for the situation.

# %%
from IPython.display import Image
Image(filename="img/flow.png", width=600,height=500)

# %% [markdown]
# ### 2. If 100.000 individuals are tested, how many will have an undiscovered cancer? <span style="color:blue"> 0.2% * 100000 = 200 </span>

# %% [markdown]
# ### 3. How many patients will be referred to the more detailed test? <span style="color:blue"> (1.99%+0.3%)* 100000 = 2290</span>

# %% [markdown]
# ### 4. Imagine that a person tests positive. What is the probability that the person does have cancer? = <span style="color:blue"> 0.3%*100000 = 300 then 300 out of 2290 = 0.13100 </span>

# %% [markdown]
# ### 5. Optional:* Before the screening program started experts, were asked to guess what fraction of the population have colon cancer. The experts guessed that 0.5% would have colon cancer, Question 1-4 were based on that guess. Now that the screening has run for several years we would like to improve our guess. We now know that 8% of those who tests positive actually have colon cancer. Based on this information what is the probability p that a person in the age-group has colon cancer? <span style="color:blue"> 0.6*P /(0.6*p)+0.02(1-p) = 0.08 then p = 0.00289</span>

# %% [markdown]
# ## Exercise 8.4: Independence of events

# %% [markdown]
# ### In the following exercise we are considering the chance operation of picking a randomly chosen person from a study population. We consider two events E1={The person smokes} and E2={The person has high income}. You have to find out whether the two events are independent. In a study of the rela- tionship between health risk and income, a large group of people living in Massachusetts were asked a series of questions. Some of their answers are shown Table 7.1.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('smoke.csv')
df
# Out:
#    Income  Smoke  Not_smoke  Total
# 0     Low    634       1846   2480
# 1  Medium    332       1622   1954
# 2    High    247       1868   2115
# 3   Total   1213       5336   6549

# %% [markdown]
# ### 1. What is the probability that someone in this study smokes ?

# %%
s = df.Smoke[3]/df.Total[3]
s
# Out:
# 0.18521911742250724

# %% [markdown]
# ### 2. If we only look at persons with high in come,then what is the probability that the person smokes?

# %%
h = df.Smoke[2]/df.Total[2]
h
# Out:
# 0.11678486997635934

# %% [markdown]
# ### 3. Is being a smoker independent of having a high income? why or why not?  <span style="color:blue"> No, that is because people with low income has higher percentage of smoker. </span>

# %% [markdown]
# ## Exercise 8.5: Frequencies and mean

# %% [markdown]
# ### The following exercise will train the concept of observations given in terms of frequencies. In a certain population of European starling (DK: stær) there are 5000 nests with young. The distribution of brood size (DK: kuld-størrelse) is given in Table 7.2. Suppose that one brood is chosen at random and the Y be the size of the brood.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

b = pd.read_csv('brood.csv')
b
# Out:
#    Brood  No_nest
# 0      1       90
# 1      2      230
# 2      3      610
# 3      4     1400
# 4      5     1760
# 5      6      750
# 6      7      130
# 7      8       26
# 8      9        3
# 9     10        1

# %% [markdown]
# ### 1. Find P(Y = 4) (The probability that the selected brood has 4 young).

# %%
y = b.No_nest[3]/b.No_nest.sum()
y
# Out:
# 0.28

# %% [markdown]
# ### 2. Find P(4 <Y <7)

# %%
p = b.No_nest[3:7].sum()/b.No_nest.sum()
p
# Out:
# 0.808

# %% [markdown]
# ### 3. What is the total number of young in the nests?

# %%
b['t'] = b.Brood*b.No_nest
b
# Out:
#    Brood  No_nest     t
# 0      1       90    90
# 1      2      230   460
# 2      3      610  1830
# 3      4     1400  5600
# 4      5     1760  8800
# 5      6      750  4500
# 6      7      130   910
# 7      8       26   208
# 8      9        3    27
# 9     10        1    10

# %%
b.t.sum()
# Out:
# 22435

# %% [markdown]
# ### 4. What is the average number of young in a nest?

# %%
b.No_nest.mean()
# Out:
# 500.0

# %% [markdown]
# ### 5. Optional*: What is the standard deviation of the size?

# %%
b['P(x)']= b.No_nest/b.No_nest.sum()
b
# Out:
#    Brood  No_nest    P(x)
# 0      1       90  0.0180
# 1      2      230  0.0460
# 2      3      610  0.1220
# 3      4     1400  0.2800
# 4      5     1760  0.3520
# 5      6      750  0.1500
# 6      7      130  0.0260
# 7      8       26  0.0052
# 8      9        3  0.0006
# 9     10        1  0.0002

# %%
b['xP(x)']= b['Brood'] * b['P(x)']
b
# Out:
#    Brood  No_nest    P(x)   xP(x)
# 0      1       90  0.0180  0.0180
# 1      2      230  0.0460  0.0920
# 2      3      610  0.1220  0.3660
# 3      4     1400  0.2800  1.1200
# 4      5     1760  0.3520  1.7600
# 5      6      750  0.1500  0.9000
# 6      7      130  0.0260  0.1820
# 7      8       26  0.0052  0.0416
# 8      9        3  0.0006  0.0054
# 9     10        1  0.0002  0.0020

# %%
c = b['xP(x)'].sum()
print("Average Brood:",c)
# Out:
# Average Brood: 4.486999999999999

# %%
b['x-u_sqr']= (b['Brood']-c)**2
b
# Out:
#    Brood  No_nest    P(x)   xP(x)    x-u_sqr
# 0      1       90  0.0180  0.0180  12.159169
# 1      2      230  0.0460  0.0920   6.185169
# 2      3      610  0.1220  0.3660   2.211169
# 3      4     1400  0.2800  1.1200   0.237169
# 4      5     1760  0.3520  1.7600   0.263169
# 5      6      750  0.1500  0.9000   2.289169
# 6      7      130  0.0260  0.1820   6.315169
# 7      8       26  0.0052  0.0416  12.341169
# 8      9        3  0.0006  0.0054  20.367169
# 9     10        1  0.0002  0.0020  30.393169

# %%
b['x-u_sqr*P(X)']= b['x-u_sqr']*b['P(x)']
b
# Out:
#    Brood  No_nest    P(x)   xP(x)    x-u_sqr  x-u_sqr*P(X)
# 0      1       90  0.0180  0.0180  12.159169      0.218865
# 1      2      230  0.0460  0.0920   6.185169      0.284518
# 2      3      610  0.1220  0.3660   2.211169      0.269763
# 3      4     1400  0.2800  1.1200   0.237169      0.066407
# 4      5     1760  0.3520  1.7600   0.263169      0.092635
# 5      6      750  0.1500  0.9000   2.289169      0.343375
# 6      7      130  0.0260  0.1820   6.315169      0.164194
# 7      8       26  0.0052  0.0416  12.341169      0.064174
# 8      9        3  0.0006  0.0054  20.367169      0.012220
# 9     10        1  0.0002  0.0020  30.393169      0.006079

# %%
ST = (b['x-u_sqr*P(X)'].sum())**0.5
print("Standard deviation of size:",ST)
# Out:
# Standard deviation of size: 1.2337872588092325

# %%
pip install mat4py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mat4py import loadmat
